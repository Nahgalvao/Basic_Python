# %% [markdown]
# <a href="https://colab.research.google.com/github/Nahgalvao/Basic_Python/blob/main/scipy_optimize_differential_evolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.differential_evolution.html

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.OptimizeResult.html#scipy.optimize.OptimizeResult

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 500)
y = np.cos(x) + np.random.normal(0, 0.2, 500)
plt.scatter(x, y, color = 'red')
plt.plot(x, np.cos(x), label='cos(x)')
plt.legend()

# %%
def fmodel(x, w):
  return w[0] + w[1]*x + w[2] * x**2 + w[3] * x**3 + w[4] * x**4 + w[5] * x**5

# %%
def rmse(w):
  y_pred = fmodel (x, w)
  return np.sqrt(sum((y - y_pred)**2) / len(y))

# %%
from scipy.optimize import differential_evolution

# %%
result = differential_evolution(rmse, [(-5, 5)]*6, maxiter = 500, popsize = 30)
parametros = result.x
print(result.nit)
# Out:
# 197

# %%
plt.scatter(x, y)
plt.plot(x, np.cos(x), "-r", label="cos(x)")
plt.plot(x, fmodel(x, parametros), "-k", label = 'result')
plt.legend
plt.show()
print(parametros)
print(result)
# Out:
# [ 0.87479809  0.74383092 -1.56045589  0.55269438 -0.06969694  0.00291515]
#  message: Optimization terminated successfully.
#  success: True
#      fun: 0.21017920419204392
#        x: [ 8.748e-01  7.438e-01 -1.560e+00  5.527e-01 -6.970e-02
#             2.915e-03]
#      nit: 197
#     nfev: 35941
#      jac: [ 2.253e-02  6.261e-02  2.182e-01  6.513e-01  8.498e-01
#             1.096e+01]

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.OptimizeResult.html#scipy.optimize.OptimizeResult

# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/10min.html#min

# %%
import numpy as np

import pandas as pd

s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object
